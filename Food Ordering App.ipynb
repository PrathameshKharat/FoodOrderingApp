# %%
class Restraurant():
    
    def __init__(self):
        print("********** Welcome! Welcome! Welcome!**********")
        self.menu()

    
    def menu(self):
        pr=True
        while pr:
            print('''
            ##############################################################################
            
            1: Register
            2: Login
            3: Today's Menu
            4: Admin Workspace
            5: User requirement
            6: Exit!!
            
            ##############################################################################''')
            print("  ")
            
            inp1=input("| | Enter your Choice | | ")
            if inp1=='1':
                self.register()
        
            elif inp1=='2':
                self.login()
                
            elif inp1=='3':
                self.Menu1()
                
            elif inp1=='4':
                print("  ")
                print("####### ADMIN WORKSPACE #######") 
                print("Press 1: All food item")
                print("Press 2: Add new food item")
                print("Press 3: Edit food item")
                print("Press 4: Delete food item")
                print("Press 5: Display all user")
                print(" ")
                input1 = input("Please enter your response: ")
                print(" ")
                
                if input1 == '1':
                    print("  ")
                    self.DisplayMenu()
                    
                elif input1 == '2':
                    print("  ")
                    self.AddItem()
                    
                elif input1 == '3':
                    print("  ")
                    self.EditFood()
                    
                elif input1 == '4':
                    print("  ")
                    self.RemoveItem()
                    
                elif input1 == '5':
                    print("  ")
                    self.DisplayUsers()
                    
            elif inp1 == '5':
                print("##### User Menu ##### ")
                print('Press 1: Place New Order')
                print("Press 2: Order History")
                print("Press 3: Update Profile")
                print("  ")
                input2 = input("Please Enter your response: ")
                print("  ")
                
                if input2 == '1':
                    print("  ")
                    self.NewOrder()
                    
                elif input2 == '2':
                    print("  ")
                    self.OrderHistory()
                    
                elif input2 == '3':
                    print("  ")
                    self.UpdateProfile()
                    
            elif inp1 == '6':
                print("Thank you!")
                pr=False
###################################################################################################

    users=[['Name','Email','Password','Contact Number','Address','Role'],
          ['Admin', 'admin', 'admin','123456','Pune','Admin']]
    Login=[['Email', 'Password', 'Role'],['Email', 'Password', 'Role']]
    Menu=[['FoodID','Name','Quantity','Price','Discount','Stock'],
        [1,'Burger','1 Piece',150,20,10],
        [2,'Chicken Biryani','500gm',500,30,15],
        [3,'Pizza','11" ',450,60,15],
        [4,'Raspberry Pie','1',250,45,3],
        [5,'Ice-Cream','1',150,20,20],
        [6,'Frozen Bottle','500 mL',880,90,15],
        [7,'Paratha','1',120,10,15],
        [8,'Dosa','1',70,11,25]]
    
                
    def register(self):
        name=input("Enter name: ")
        phoneno=input("Enter phone number: ")
        address = input("Enter your Address: ")
        email = input("Enter your Email: ")
        password=input("Enter password: ")
        role='Customer'
        for i in range(len(self.users)):
            if email in self.users[i]:
                print("User Already Existed!! Login with the credentials")
                break
        else:
            self.users.append([name,email,password,phoneno,address,role])
            print("User Registered Successfully!! Login to Order")
    
    count1=0
            
    def login(self):
        self.email = input("Please enter your registered email: ")
        self.password = input("Please enter your password: ")
        for i in range(len(self.users)):
            if self.email == self.users[i][1] and self.password == self.users[i][2]:
                self.count1 = 1
                self.Login.clear()
                self.Login.append(['Email', 'Password', 'Role'])
                self.Login.append([self.users[i][1], self.users[i][2], self.users[i][-1]])
                break
            else:
                self.count1 = 0

        if self.count1 == 1:
            print("Welcome! You are successfully logged in.")
        elif self.count1 == 0:
            print("User not found! Please Register.")

    def Menu1(self):  
        print(self.Menu)
        
    def DisplayMenu(self):
        print(self.Menu)
    
    @classmethod
    def AddItem(cls):
        if cls.Login[1][2] == "Admin":
            srno = len(cls.Menu) 
            foodName = input("Enter the Food Name: ")
            foodQuantity = input("Enter the Food Quantity: ")
            foodPrice= int(input("Enter Food Price: "))
            foodDiscount = int(input("Enter Discount: "))
            foodStock = input("Enter Stock Available: ")
            cls.Menu.append([srno,foodName,foodQuantity,foodPrice,foodDiscount,foodStock])
            print("Food Item added successfully!")
        else:
            print("************ ERROR 404 ***************")
            
    def EditFood(self):
            if self.Login[1][2]=='Admin':
                self.DisplayMenu()
                editfood = int(input("Please enter Food Number to edit: "))
                for i in range(len(self.Menu)):
                    if editfood in self.Menu[i]:
                        print(self.Menu[i])
                        inp3=input("Press Y to continue editing or press N? Y/N: ")
                        if inp3.lower()=='y':
                            print("Press 1: Edit Name: ")
                            print("Press 2: Edit Quantity: ")
                            print("Press 3: Edit Food Price: ")
                            print("Press 4: Edit Discount: ")
                            print("Press 5: Edit Stock: ")
                            print(" ")
                            inp4 = input("Please enter your response: ")
                            if inp4 == '1':
                                self.Menu[i][2] = input("Please enter new name: ")
                                print("Changes Applied")
                            elif inp4 == '2':
                                self.Menu[i][2] = input("Please enter new quantity: ")
                                print("Changes Applied")
                            elif inp4 == '3':
                                self.Menu[i][2] = int(input("Please enter new price: "))
                                print("Changes Applied")
                            elif inp4 == '4':
                                self.Menu[i][2] = int(input("Please enter new discount: "))
                                print("Changes Applied")
                            elif inp4 == '5':
                                self.Menu[i][2] = input("Please enter new stock: ")
                                print("Changes Applied")
                            else:
                                print("Wrong Instructions")
                            break
                else:
                    print("Please select proper id")
            else:
                print("************ ERROR 404 ***************")
            
    def RemoveItem(self):
        if self.Login[1][2] == "Admin":
            self.DisplayMenu()
            foodid = input("Enter Serial number to remove item: ")
            for j in range(len(self.Menu)):
                if foodid in self.Menu[j]:
                    print(self.Menu[j])
                    resp= input("Do you want to remove this item? Y/N: ")
                    if resp.lower() == 'y':
                        removed=self.Menu.pop(j)
                        removedItem.append(removed)
                        print("Food Item Removed")
                    else:
                        print("Wrong Instructions! Program Cancelled")
                    break
            else:
                print("Please enter right Serial Number!")    
        else:
            print("************ ERROR 404 ***************")
            
    def DisplayUsers(self):
        if self.Login[1][2] == "Admin":
            userlistindb = [['Name','Email','Password','Contact Number','Address','Role']]
            for i in range(len(self.users)):
                if self.users[i][-1] == "User":
                    userlistindb.append(self.users[i])
            print(userlistindb)
        else:
            print("************ ERROR 404 ***************e")
            
    def NewOrder(self):
        if self.Login[1][2] == "Admin" or self.Login[1][2] == 'User':
            self.DisplayMenu()
            list1 = ['Name','Quantity','Price','Discount','Final Price']
            present_order = []
            resp1 = list(input("Please enter the Serial Number of food to order: "))
            for i in resp1:
                if i.isnumeric()==False:
                    resp1.remove(i)
            for j in range(0,len(resp1)):
                for i in range(0,len(self.Menu)):
                    if int(resp1[j]) == self.Menu[i][0]:
                        newlist1 = copy.deepcopy(self.Menu[i][2:6])
                        newlist1.append(newlist1[2] - newlist1[3])
                        present_order.append(newlist1)               
            print("You are ordering : ")
            print(tabulate(present_order, headers=list1, tablefmt='fancy_grid'))
            resp2 = input("Do you want to proceed? Y/N: ")
            if resp2.lower()=="y":
                sum1 = 0
                for k in range(len(present_order)):
                    sum1 += present_order[k][-1]
                print("Please pay {0}".format(sum1))
                confirm = input("Please type 'CONFIRM' to pay ₹{} : ".format(sum1))
                if confirm == 'CONFIRM':
                    print("Order Successful. Enjoy!")
                    for l in range(len(present_order)):
                        self.orderHistory.append([self.active_user[1][0],present_order[l][0],present_order[l][-1]])
                else:
                    print("Payment cancelled!")
            else:
                print("Order cancelled")
        else:
            print("************ ERROR 404 ***************")
            
    def UpdateProfile(self):
        if self.Login[1][2] == "Admin" or self.Login[1][2] == 'Customer':
            userid = input("Please enter your email id: ")
            for i in range(len(self.users)):
                if userid in self.users[i]:
                    print('''Press 1: Edit Name: 
                    Press 2: Edit Contact no.: 
                    Press 3: Edit Address: 
                    Press 4: Edit Password: ''')

                    input12 = input("Please enter your response: ")
                    if input12 == '1':
                        self.users[i][0] = input("Please enter new name: ")
                        print(" ")
                        print("Changes Applied!")
                    elif input12 == '2':
                        self.users[i][3] = input("Please enter new Contact no.: ")
                        print(" ")
                        print("Changes Applied!")
                    elif input12 == '3':
                        self.users[i][4] = input("Please enter new Address: ")
                        print(" ")
                        print("Changes Applied!")
                    elif input12 == '4':
                        self.users[i][2] = input("Please enter new Password: ")
                        print(" ")
                        print("Changes Applied!")
                    break
            else:
                print("User Not FOund")
        else:
            print("************ ERROR 404 ***************")
            
    def OrderHistory(self):
        if self.Login[1][2] == "Admin" or self.Login[1][2] == "Customer":
            new_list3 = []
            for i in range(len(self.orderHistory)):
                if self.active_user[1][0] in self.orderHistory[i][0]:
                    new_list3.append(self.orderHistory[i])
            print(new_list3)
        else:
            print("************ ERROR 404 ***************")
            
rest=Restraurant()
# Out:
# ********** Welcome! Welcome! Welcome!**********
#
#             ##############################################################################
#
#             1: Register
#             2: Login
#             3: Today's Menu
#             4: Admin Workspace
#             5: User requirement
#             6: Exit!!
#
#             ##############################################################################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-efbf2205d60e> in <module>
#     306             print("************ ERROR 404 ***************")
#     307
# --> 308 rest=Restraurant()
#
# <ipython-input-1-efbf2205d60e> in __init__(self)
#       3     def __init__(self):
#       4         print("********** Welcome! Welcome! Welcome!**********")
# ----> 5         self.menu()
#       6
#       7
#
# <ipython-input-1-efbf2205d60e> in menu(self)
# ...
